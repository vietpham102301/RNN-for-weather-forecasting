# %%
import matplotlib as matplotlib
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
file_path = 'data/Data_Weather_processed.csv'
data=pd.read_csv(file_path)
data.head(24)
# Out:
#                FALSE  max  min  wind  rain  humidi  day  month  year
# 0   Ho Chi Minh City   32   25    18   0.0      71    4      1  2019  \
# 1   Ho Chi Minh City   34   24     5   0.0      61    4      1  2020
# 2   Ho Chi Minh City   32   24     8   0.0      68    4      1  2021
# 3   Ho Chi Minh City   31   21     5   0.0      77    5      1  2009
# 4   Ho Chi Minh City   35   26    10   0.0      57    5      1  2010
# 5   Ho Chi Minh City   32   24     6   2.5      74    5      1  2011
# 6   Ho Chi Minh City   33   23     5   0.0      76    5      1  2012
# 7   Ho Chi Minh City   29   22     5   0.0      72    5      1  2013
# 8   Ho Chi Minh City   31   23     6   1.7      79    5      1  2014
# 9   Ho Chi Minh City   33   24     5   1.1      70    5      1  2015
# 10  Ho Chi Minh City   33   25     8   0.4      66    5      1  2016
# 11  Ho Chi Minh City   32   24     9   1.6      72    5      1  2017
# 12  Ho Chi Minh City   33   26     9   0.1      70    5      1  2018
# 13  Ho Chi Minh City   32   25    16   0.0      68    5      1  2019
# 14  Ho Chi Minh City   35   25     6   0.0      60    5      1  2020
# 15  Ho Chi Minh City   26   25     5   3.4      77    5      1  2021
# 16  Ho Chi Minh City   32   22     5   0.3      77    6      1  2009
# 17  Ho Chi Minh City   34   25    12   0.0      56    6      1  2010
# 18  Ho Chi Minh City   33   23     7   3.2      74    6      1  2011
# 19  Ho Chi Minh City   33   23     6   0.4      74    6      1  2012
# 20  Ho Chi Minh City   26   22     8   8.8      84    6      1  2013
# 21  Ho Chi Minh City   30   23     6   0.2      76    6      1  2014
# 22  Ho Chi Minh City   33   25     6   4.7      74    6      1  2015
# 23  Ho Chi Minh City   34   25    13   0.1      67    6      1  2016
#
#                             label
# 0                           Sunny
# 1                   Partly cloudy
# 2            Patchy rain possible
# 3                   Partly cloudy
# 4                   Partly cloudy
# 5            Patchy rain possible
# 6                   Partly cloudy
# 7            Patchy rain possible
# 8            Patchy rain possible
# 9          Moderate rain at times
# 10                         Cloudy
# 11           Patchy rain possible
# 12         Moderate rain at times
# 13                          Sunny
# 14                          Sunny
# 15                       Overcast
# 16                  Partly cloudy
# 17                          Sunny
# 18           Patchy rain possible
# 19                  Partly cloudy
# 20  Moderate or heavy rain shower
# 21                         Cloudy
# 22         Moderate rain at times
# 23                  Partly cloudy

# %%
temperature = np.array(data['max'])

# %%
batch_size = 100
extra_day = 1
x_train = temperature[:(len(temperature)-(batch_size*9))]
x_batches = x_train.reshape(-1, batch_size, 1)
print(len(x_batches))
print(x_batches)

y_train = temperature[1:(len(temperature)-(batch_size*9))+extra_day]
y_batches = y_train.reshape(-1, batch_size, 1)
print(len(y_batches))
# Out:
# 36
# [[[32]
#   [34]
#   [32]
#   ...
#   [32]
#   [33]
#   [33]]
#
#  [[34]
#   [34]
#   [32]
#   ...
#   [31]
#   [36]
#   [25]]
#
#  [[34]
#   [33]
#   [34]
#   ...
#   [32]
#   [33]
#   [34]]
#
#  ...
#
#  [[29]
#   [35]
#   [28]
#   ...
#   [32]
#   [31]
#   [31]]
#
#  [[32]
#   [31]
#   [33]
#   ...
#   [30]
#   [33]
#   [31]]
#
#  [[32]
#   [34]
#   [33]
#   ...
#   [33]
#   [33]
#   [27]]]
# 36

# %%
def test_data(series, forecast, num_of_testing_sample):
    testX = temperature[-(num_of_testing_sample + forecast):][:num_of_testing_sample].reshape(-1, batch_size, 1)
    print(len(testX))
    testY = temperature[-(num_of_testing_sample):].reshape(-1, batch_size, 1)
    print(len(testY))
    return testX, testY
X_test, Y_test = test_data(temperature, extra_day, 900)
print(X_test.shape)
# Out:
# 9
# 9
# (9, 100, 1)

# %%
tf.reset_default_graph()
rnn_size = 100
learning_rate=0.001
time_step = batch_size
X = tf.placeholder(tf.float32, [None, time_step, 1])
Y = tf.placeholder(tf.float32, [None, time_step, 1])

rnn_cells=tf.contrib.rnn.BasicRNNCell(num_units=rnn_size, activation=tf.nn.relu)
rnn_output, states = tf.nn.dynamic_rnn(rnn_cells, X, dtype=tf.float32)

output=tf.reshape(rnn_output, [-1, rnn_size])
logit=tf.layers.dense(output, 1, name="softmax")

outputs=tf.reshape(logit, [-1, batch_size, 1])
print(logit)

loss = tf.reduce_sum(tf.square(outputs - Y))

accuracy = tf.reduce_mean(tf.cast(tf.equal(tf.argmax(logit, 1), tf.cast(Y, tf.int64)), tf.float32))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
train_step=optimizer.minimize(loss)

# %%
epochs = 1000

sess = tf.Session()
init = tf.global_variables_initializer()
sess.run(init)

for epoch in range(epochs):
    train_dict = {X: x_batches, Y: y_batches, dropout_keep_prob:0.5}
    sess.run(train_step, feed_dict=train_dict)

# %%
epochs = 1000

sess = tf.Session()
init = tf.global_variables_initializer()
sess.run(init)

for epoch in range(epochs):
    train_dict = {X: x_batches, Y: y_batches, dropout_keep_prob:0.5}
    sess.run(train_step, feed_dict=train_dict)

# %%
saver = tf.train.Saver()
save_path = saver.save(sess, "models/model.ckpt")

# %%
with tf.Session() as sess:
  # Restore variables from disk.
    saver.restore(sess, "models/model.ckpt")
    y_pred=sess.run(outputs, feed_dict={X: X_test})
    print (y_pred)

# %%
plt.title("Compare Weather Forecast vs Actual", fontsize=14)
plt.plot(pd.Series(np.ravel(Y_test)), "bo", markersize=10, label="Actual")
plt.plot(pd.Series(np.ravel(y_pred)), "r.", markersize=10, label="Forecast")
plt.legend(loc="upper left")
plt.xlabel("Time Periods")
plt.show()
